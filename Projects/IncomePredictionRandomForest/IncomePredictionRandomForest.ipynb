# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Reading Dataset

# %%
df = pd.read_csv('/content/income_evaluation.csv')

# %%
df
# Out:
#        age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0       39          State-gov    77516  ...              40    United-States   <=50K
# 1       50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2       38            Private   215646  ...              40    United-States   <=50K
# 3       53            Private   234721  ...              40    United-States   <=50K
# 4       28            Private   338409  ...              40             Cuba   <=50K
# ...    ...                ...      ...  ...             ...              ...     ...
# 32556   27            Private   257302  ...              38    United-States   <=50K
# 32557   40            Private   154374  ...              40    United-States    >50K
# 32558   58            Private   151910  ...              40    United-States   <=50K
# 32559   22            Private   201490  ...              20    United-States   <=50K
# ...

# %% [markdown]
# #Showing first 50 entries

# %%
df.head(50)
# Out:
#     age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0    39          State-gov    77516  ...              40    United-States   <=50K
# 1    50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2    38            Private   215646  ...              40    United-States   <=50K
# 3    53            Private   234721  ...              40    United-States   <=50K
# 4    28            Private   338409  ...              40             Cuba   <=50K
# 5    37            Private   284582  ...              40    United-States   <=50K
# 6    49            Private   160187  ...              16          Jamaica   <=50K
# 7    52   Self-emp-not-inc   209642  ...              45    United-States    >50K
# 8    31            Private    45781  ...              50    United-States    >50K
# 9    42            Private   159449  ...              40    United-States    >50K
# ...

# %% [markdown]
# #Categorical values converting into numerical values

# %%
from sklearn.preprocessing import LabelEncoder
df = df.apply(LabelEncoder().fit_transform)
df.head(60)
# Out:
#     age   workclass   fnlwgt  ...   hours-per-week   native-country   income
# 0    22           7     2671  ...               39               39        0
# 1    33           6     2926  ...               12               39        0
# 2    21           4    14086  ...               39               39        0
# 3    36           4    15336  ...               39               39        0
# 4    11           4    19355  ...               39                5        0
# 5    20           4    17700  ...               39               39        0
# 6    32           4     8536  ...               15               23        0
# 7    35           6    13620  ...               44               39        1
# 8    14           4     1318  ...               49               39        1
# 9    25           4     8460  ...               39               39        1
# 10   20           4    17530  ...               76               39        1
# ...

# %%
df.describe()
# Out:
#                 age     workclass  ...   native-country        income
# count  32561.000000  32561.000000  ...     32561.000000  32561.000000
# mean      21.580326      3.868892  ...        36.718866      0.240810
# std       13.635502      1.455960  ...         7.823782      0.427581
# min        0.000000      0.000000  ...         0.000000      0.000000
# 25%       11.000000      4.000000  ...        39.000000      0.000000
# 50%       20.000000      4.000000  ...        39.000000      0.000000
# 75%       31.000000      4.000000  ...        39.000000      0.000000
# max       72.000000      8.000000  ...        41.000000      1.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# #checking for missing values

# %%
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['age'])
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# co-relation heatmap

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
#correlation heatmap of dataset
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = "YlGn",
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Corelations', y=1.05, size=15)

correlation_heatmap(df)

# %% [markdown]
# #Initiating variables

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
X
# Out:
# array([[   22,     7,  2671, ...,     0,    39,    39],
#        [   33,     6,  2926, ...,     0,    12,    39],
#        [   21,     4, 14086, ...,     0,    39,    39],
#        ...,
#        [   41,     4,  7883, ...,     0,    39,    39],
#        [    5,     4, 12881, ...,     0,    19,    39],
#        [   35,     5, 17825, ...,     0,    39,    39]])

# %%
print(y)
# Out:
# [0 0 0 ... 0 0 1]

# %% [markdown]
# #Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# #Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #Training the model using Random Forest algorithm on training dataset

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier()
randomforest.fit(X_train, y_train)
#y_pred = randomforest.predict(X_test)
score_randomforest = randomforest.score(X_test,y_test)*100
print('The accuracy of the Random Forest Model is', score_randomforest)
# Out:
# The accuracy of the Random Forest Model is 85.51774966220366

# %% [markdown]
# #Testing the model

# %%
y_pred = randomforest.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %% [markdown]
# #The accuracy of the Random Forest Model is 85.51774966220366

# %%
output = df.predict(sc.transform([[30,7,34445,33,3,5,9,1,3,1,1,1,90,58]]))
output
# Out:
# array([0.383])

# %%
output = df.predict(sc.transform([[15,4,13217,7,11,4,12,1,1,1,0,0,49,39]]))
output
# Out:
# array([0.142])

# %%
output = df.predict(sc.transform([[35,6,13620,11,8,2,4,0,4,1,0,0,44,39]]))
output
# Out:
# array([0.317])

# %% [markdown]
# #Using Decision Tree Classifier Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion= 'entropy')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)*100
# Out:
# [[5368  791]
#  [ 775 1207]]
# 80.76403390246898

# %% [markdown]
# Getting 80% accuracy using decision tree.

# %%
output = classifier.predict(sc.transform([[26,6,10000,12,12,3,10,5,2,0,1,0,39,26]]))
output
# Out:
# array([0])

# %%
output = classifier.predict(sc.transform([[40,7,45700,10,20,6,12,7,1,1,0,1,57,44]]))
output
# Out:
# array([1])
